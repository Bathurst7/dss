# %%
import pandas as pd

df = pd.read_csv('../final_data.csv')
df.head()
# Out:
#    Company name    TSR     Time  Engineered_PRASM  Engineered_RASM  \
# 0             0  0.161  2013.25         23152.375       28205.6325
# 1             0  0.156  2013.50         24162.000       29316.5600
# 2             0  0.096  2013.75         25171.875       30407.6250
# 3             0  0.165  2014.00         26182.000       30210.0000
# 4             0  0.181  2014.25         27836.935       29206.6250
#
#    Engineered_CASM  Engineered_Load_factor  Engineered_Gross_profit_margin  \
# 0       227.497250              1723.34200                      479.958800
# 1       229.539000              1711.47500                      527.939700
# 2       251.517375              1719.74250                      617.214375
# 3       262.222800              1723.98400                      472.283000
# 4       271.923750              1641.61375                      154.895825
#
#    Engineered_Quick_ratio  Engineered_D/E  ...  \
# 0               2234.7075       1409.2750  ...
# 1               2214.8500       1365.1530  ...
# 2               2295.6750       1389.4875  ...
# 3               2175.1200       1490.3600  ...
# 4               2155.2475       1490.5450  ...
#
#    Engineered_Gross_profit_margin_lag2  Engineered_Quick_ratio_lag1  \
# 0                             0.000000                       0.0000
# 1                             0.000000                    2234.7075
# 2                           479.958800                    2214.8500
# 3                           527.939700                    2295.6750
# 4                           617.214375                    2175.1200
#
#    Engineered_Quick_ratio_lag2  Engineered_D/E_lag1  Engineered_D/E_lag2  \
# 0                       0.0000               0.0000               0.0000
# 1                       0.0000            1409.2750               0.0000
# 2                    2234.7075            1365.1530            1409.2750
# 3                    2214.8500            1389.4875            1365.1530
# 4                    2295.6750            1490.3600            1389.4875
#
#    Engineered_ROA_lag1  Engineered_ROA_lag2  Engineered_EPS_lag1  \
# 0             0.000000             0.000000               0.0000
# 1           114.151275             0.000000            1248.2150
# 2           124.837000           114.151275            1510.1250
# 3           165.127500           124.837000            4168.4625
# 4           176.426400           165.127500            2235.5400
#
#    Engineered_EPS_lag2  TSR_rolling_mean
# 0               0.0000            0.0000
# 1               0.0000            0.0000
# 2            1248.2150            0.0000
# 3            1510.1250            0.1445
# 4            4168.4625            0.1495
#
# [5 rows x 33 columns]

# %%
def split_data(df, year_split=2022):
    """
    Split the data into training and test sets based on the year column.
    
    Parameters:
    - df: DataFrame containing the full dataset.
    - target_column: The name of the target variable column.
    - year_split: The year to split on (default is 2022).
    
    Returns:
    - train_data: DataFrame containing the training data.
    - test_data: DataFrame containing the test data.
    """
    train_data = df[df['Time'] <= year_split]
    test_data = df[df['Time'] > year_split]
    
    return train_data, test_data

# %%
train_data, test_data = split_data(df)
print(train_data.shape)
print(test_data.shape)
# Out:
# (324, 33)
# (72, 33)

# %%
import joblib

def scale_data(data, scaler_path):
    scaler = joblib.load(scaler_path)
    
    scaled_col = data.drop(['Company name', 'TSR', 'Time'], axis=1)
    
    data_scaled = scaler.transform(scaled_col)
    scaled_df = pd.DataFrame(data_scaled, columns=scaled_col.columns, index=data.index)
    final_data_scaled = data[['Company name', 'TSR', 'Time']].join(scaled_df)
    
    return final_data_scaled

# %% [markdown]
# # models

# %%
scaler_path = './scaler_folder/minmax_scaler.joblib'
train_data_scaled = scale_data(train_data, scaler_path)
train_data_scaled
# Out:
#      Company name     TSR     Time  Engineered_PRASM  Engineered_RASM  \
# 0               0  0.1610  2013.25          0.322983         0.235652
# 1               0  0.1560  2013.50          0.337168         0.245119
# 2               0  0.0960  2013.75          0.351356         0.254418
# 3               0  0.1650  2014.00          0.365548         0.252733
# 4               0  0.1810  2014.25          0.388800         0.244182
# ..            ...     ...      ...               ...              ...
# 383             8  0.0667  2021.00          0.241608         0.176123
# 384             8  0.2553  2021.25          0.298718         0.310505
# 385             8  0.0690  2021.50          0.182309         0.195118
# 386             8 -0.1613  2021.75          0.273228         0.245109
# 387             8 -0.1346  2022.00          0.281784         0.267542
#
#      Engineered_CASM  Engineered_Load_factor  Engineered_Gross_profit_margin  \
# 0           0.000452                0.008172                        0.859217
# 1           0.000483                0.008098                        0.869678
# 2           0.000816                0.008149                        0.889141
# 3           0.000978                0.008176                        0.857544
# 4           0.001125                0.007665                        0.788349
# ..               ...                     ...                             ...
# 383         0.538815                0.004457                        0.576616
# 384         0.431977                0.005009                        0.824160
# 385         0.447349                0.005636                        0.890805
# 386         0.432085                0.009644                        0.895847
# 387         0.456653                0.007517                        0.907899
#
#      Engineered_Quick_ratio  Engineered_D/E  ...  \
# 0                  0.191851        0.569805  ...
# 1                  0.190146        0.568586  ...
# 2                  0.197085        0.569258  ...
# 3                  0.186735        0.572045  ...
# 4                  0.185029        0.572050  ...
# ..                      ...             ...  ...
# 383                0.189119        0.763728  ...
# 384                0.194349        0.719636  ...
# 385                0.258585        0.719101  ...
# 386                0.244731        0.716331  ...
# 387                0.253441        0.716913  ...
#
#      Engineered_Gross_profit_margin_lag2  Engineered_Quick_ratio_lag1  \
# 0                               0.754579                     0.000000
# 1                               0.754579                     0.191851
# 2                               0.859217                     0.190146
# 3                               0.869678                     0.197085
# 4                               0.889141                     0.186735
# ..                                   ...                          ...
# 383                             0.000000                     0.170013
# 384                             0.406936                     0.189119
# 385                             0.576616                     0.194349
# 386                             0.824160                     0.258585
# 387                             0.890805                     0.244731
#
#      Engineered_Quick_ratio_lag2  Engineered_D/E_lag1  Engineered_D/E_lag2  \
# 0                       0.000000             0.530865             0.530865
# 1                       0.000000             0.569805             0.530865
# 2                       0.191851             0.568586             0.569805
# 3                       0.190146             0.569258             0.568586
# 4                       0.197085             0.572045             0.569258
# ..                           ...                  ...                  ...
# 383                     0.095404             0.749182             0.655363
# 384                     0.170013             0.763728             0.749182
# 385                     0.189119             0.719636             0.763728
# 386                     0.194349             0.719101             0.719636
# 387                     0.258585             0.716331             0.719101
#
#      Engineered_ROA_lag1  Engineered_ROA_lag2  Engineered_EPS_lag1  \
# 0               0.478699             0.478699             0.529480
# 1               0.697455             0.478699             0.564614
# 2               0.717933             0.697455             0.571986
# 3               0.795144             0.717933             0.646812
# 4               0.816797             0.795144             0.592405
# ..                   ...                  ...                  ...
# 383             0.161155             0.357505             0.065346
# 384             0.000000             0.161155             0.165977
# 385             0.393483             0.000000             0.245013
# 386             0.452357             0.393483             0.441853
# 387             0.369828             0.452357             0.163566
#
#      Engineered_EPS_lag2  TSR_rolling_mean
# 0               0.529480          0.856352
# 1               0.529480          0.856352
# 2               0.564614          0.856352
# 3               0.571986          0.866079
# 4               0.646812          0.866415
# ..                   ...               ...
# 383             0.000000          0.847861
# 384             0.065346          0.858469
# 385             0.165977          0.865520
# 386             0.245013          0.860217
# 387             0.441853          0.856830
#
# [324 rows x 33 columns]

# %%
scaler_path = './scaler_folder/minmax_scaler.joblib'
test_data_scaled = scale_data(test_data, scaler_path)
test_data_scaled.head()
# Out:
#     Company name     TSR     Time  Engineered_PRASM  Engineered_RASM  \
# 36             0  0.0909  2022.25          0.381261         0.250341
# 37             0 -0.0413  2022.50          0.401199         0.264162
# 38             0  0.0598  2022.75          0.423984         0.277986
# 39             0  0.0400  2023.00          0.418353         0.272849
# 40             0  0.1000  2023.25          0.395664         0.260813
#
#     Engineered_CASM  Engineered_Load_factor  Engineered_Gross_profit_margin  \
# 36         0.462839                0.007142                        0.906154
# 37         0.453702                0.007832                        0.910186
# 38         0.441496                0.008147                        0.913821
# 39         0.447683                0.007960                        0.917060
# 40         0.456937                0.007523                        0.919992
#
#     Engineered_Quick_ratio  Engineered_D/E  ...  \
# 36                0.239584        0.567185  ...
# 37                0.237877        0.567748  ...
# 38                0.236170        0.568312  ...
# 39                0.234462        0.568317  ...
# 40                0.232754        0.568880  ...
#
#     Engineered_Gross_profit_margin_lag2  Engineered_Quick_ratio_lag1  \
# 36                             0.911979                     0.253441
# 37                             0.916231                     0.239584
# 38                             0.906154                     0.237877
# 39                             0.910186                     0.236170
# 40                             0.913821                     0.234462
#
#     Engineered_Quick_ratio_lag2  Engineered_D/E_lag1  Engineered_D/E_lag2  \
# 36                     0.255146             0.567181             0.566617
# 37                     0.253441             0.567185             0.567181
# 38                     0.239584             0.567748             0.567185
# 39                     0.237877             0.568312             0.567748
# 40                     0.236170             0.568317             0.568312
#
#     Engineered_ROA_lag1  Engineered_ROA_lag2  Engineered_EPS_lag1  \
# 36             0.573247             0.567811             0.779903
# 37             0.581009             0.573247             0.802702
# 38             0.587223             0.581009             0.825508
# 39             0.593051             0.587223             0.848318
# 40             0.598493             0.593051             0.871135
#
#     Engineered_EPS_lag2  TSR_rolling_mean
# 36             0.757109          0.860404
# 37             0.779903          0.858179
# 38             0.802702          0.857784
# 39             0.825508          0.858866
# 40             0.848318          0.859019
#
# [5 rows x 33 columns]

# %%
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score

def gradient_boosting_train(train_data, target_column, feature_columns, n_splits=5, scoring='neg_root_mean_squared_error'):
  param_grid = {
    'learning_rate': [0.05, 0.2, 0.1],
    'min_samples_split':[2, 3, 5],
    'max_depth': [3, 4, 5],
    'min_samples_leaf': [1, 3, 5],
    'subsample': [0.6, 0.8, 1.0],
    'n_estimators': [100, 200, 300]
  }
  X_train = train_data[feature_columns]
  y_train = train_data[target_column]
  gbr = GradientBoostingRegressor(random_state=42)
  tscv = TimeSeriesSplit(n_splits=n_splits)
  
  grid_search = GridSearchCV(estimator=gbr, param_grid=param_grid, cv=tscv, scoring=scoring, n_jobs=-1, verbose=2)
  grid_search.fit(X_train, y_train)
  
  # get best params + estimators
  best_params = grid_search.best_params_
  best_model = grid_search.best_estimator_
  
  # calculate r2
  y_train_pred = best_model.predict(X_train)
  r2_train = r2_score(y_train, y_train_pred)
  
  return best_model, best_params, r2_train

# %%
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

def train_random_forest(train_data, target_column, feature_columns, n_splits=5, scoring='neg_root_mean_squared_error'):
    
    # Define the hyperparameter grid for Random Forest inside the function
    param_grid = {
        'n_estimators': [100, 200, 300],
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'max_features': ['sqrt', 'log2', None]
    }
    
    X_train = train_data[feature_columns]
    y_train = train_data[target_column]
    
    rf = RandomForestRegressor(random_state=42)
    tscv = TimeSeriesSplit(n_splits=n_splits)
    
    grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=tscv, scoring=scoring, n_jobs=-1, verbose=2)
    grid_search.fit(X_train, y_train)
    
    best_params = grid_search.best_params_
    best_model = grid_search.best_estimator_
    
    # Calculate R² on the training data
    y_train_pred = best_model.predict(X_train)
    r2_train = r2_score(y_train, y_train_pred)
    
    return best_model, best_params, r2_train

# %%
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from xgboost.sklearn import XGBRegressor 
from sklearn.metrics import r2_score

def train_xgb(train_data, target_column, feature_columns, n_splits=5, scoring='neg_root_mean_squared_error'):
    param_grid = {
        'learning_rate': [0.3, 0.5, 0.7], 
        "gamma":[ 0.0, 0.1, 0.2],
        "max_depth": [3, 5, 6, 10],
        "min_child_weight": [ 1, 3, 5, 7],
        "colsample_bytree":[ 0.3, 0.4, 0.7],
        'n_estimators': [100, 200, 300]
    }
    
    X_train = train_data[feature_columns]
    y_train = train_data[target_column]
    
    xgb = XGBRegressor(random_state=42)
    tscv = TimeSeriesSplit(n_splits=n_splits)
    
    grid_search = GridSearchCV(estimator=xgb, param_grid=param_grid, cv=tscv, scoring=scoring, n_jobs=-1, verbose=2)
    grid_search.fit(X_train, y_train)
    
    best_params = grid_search.best_params_
    best_model = grid_search.best_estimator_
    
    # Calculate R² on the training data
    y_train_pred = best_model.predict(X_train)
    r2_train = r2_score(y_train, y_train_pred)
    
    return best_model, best_params, r2_train

# %% [markdown]
# # evaluate

# %%
from sklearn.metrics import mean_squared_error

def evaluate_model(model, test_data, target_column, feature_columns):
  X_test = test_data[feature_columns]
  y_test = test_data[target_column]
  y_pred = model.predict(X_test)
  # Calculate RMSE
  rmse = mean_squared_error(y_test, y_pred, squared=False)
  # Calculate R² score\n",
  # r2 = r2_score(y_test, y_pred)\n",
  return rmse

# %%
import joblib
def save_file(scaler, filename):
  joblib.dump(scaler, filename)

# %%
feature_columns = [col for col in train_data_scaled.columns if col != "TSR"]

# %% [markdown]
# ### gradient boosting

# %%
best_model, best_params, r2_train = gradient_boosting_train(train_data_scaled, target_column="TSR", feature_columns=feature_columns)
# evaluation
rmse = evaluate_model(best_model, test_data_scaled, target_column="TSR", feature_columns=feature_columns)

print(f"\n Best Hyperparameters: {best_params}"),
print(f"\n R2 on Train-set: {r2_train}"),
print(f"\n Root Mean Squared Error (RMSE) on Test Set: {rmse}")
# Out:
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
#
#  Best Hyperparameters: {'learning_rate': 0.2, 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'subsample': 0.6}
#
#  R2 on Train-set: 0.9999900162859513
#
#  Root Mean Squared Error (RMSE) on Test Set: 0.07124991802932935
# d:\Probability\envs\deployment\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
gbr_path = "./model_folder/gbr.joblib"
save_file(best_model, gbr_path)

# %% [markdown]
# ### random forest

# %%
best_model, best_params, r2_train = train_random_forest(train_data_scaled, target_column="TSR", feature_columns=feature_columns)
# evaluation
rmse = evaluate_model(best_model, test_data_scaled, target_column="TSR", feature_columns=feature_columns)

print(f"\n Best Hyperparameters: {best_params}"),
print(f"\n R2 on Train-set: {r2_train}"),
print(f"\n Root Mean Squared Error (RMSE) on Test Set: {rmse}")
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
#
#  Best Hyperparameters: {'max_depth': 20, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
#
#  R2 on Train-set: 0.4132775851563426
#
#  Root Mean Squared Error (RMSE) on Test Set: 0.1949319786871062
# d:\Probability\envs\deployment\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
rf_path = "./model_folder/random_forest.joblib"
save_file(best_model, rf_path)

# %% [markdown]
# ### xgb

# %%
best_model, best_params, r2_train = train_random_forest(train_data_scaled, target_column="TSR", feature_columns=feature_columns)
# evaluation
rmse = evaluate_model(best_model, test_data_scaled, target_column="TSR", feature_columns=feature_columns)

print(f"\n Best Hyperparameters: {best_params}"),
print(f"\n R2 on Train-set: {r2_train}"),
print(f"\n Root Mean Squared Error (RMSE) on Test Set: {rmse}")

# %%
xgb_path = "./model_folder/xgb.joblib"
save_file(best_model, xgb_path)
